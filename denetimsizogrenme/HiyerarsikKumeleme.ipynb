# %% [markdown]
# <a href="https://colab.research.google.com/github/AycaCicek/DenetimsizOgrenme/blob/main/HiyerarsikKumeleme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage

# %%
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=FutureWarning)

# %%
data=pd.read_csv("/content/USArrests.csv",index_col=0)

# %%
hc_complete=linkage(data,"complete")#dendogram için "complete"
hc_average=linkage(data,"average")

# %%
from scipy.cluster.hierarchy import dendrogram

# %%
plt.figure(figsize=(10,5))
plt.title("Hiyerarşik kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")

dendrogram(hc_complete,
           leaf_font_size=10);

# %%
plt.figure(figsize=(5,3))
plt.title("Hiyerarşik kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")
#-->lastp:p adet küme 
#-->show_contracted:eleman bilgisi
dendrogram(hc_complete,
           truncate_mode="lastp",
           p=4,
           show_contracted=True,
           leaf_font_size=10);

# %%
plt.figure(figsize=(5,3))
plt.title("Hiyerarşik kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")
#-->lastp:p adet küme 
#-->show_contracted:eleman bilgisi
dendrogram(hc_complete,
           truncate_mode="lastp",
           p=10,
           show_contracted=True,
           leaf_font_size=10);

# %%
#average yöntemi
plt.figure(figsize=(10,5))
plt.title("Hiyerarşik kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")

dendrogram(hc_average,
           leaf_font_size=10);
